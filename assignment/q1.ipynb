# %% [markdown]
# # Dropout and Data Augmentation
# In this exercise we will implement two ways to reduce overfitting.
#
# Like the previous assignment, we will train ConvNets to recognize the categories in CIFAR-10. However unlike the previous assignment where we used 49,000 images for training, in this exercise we will use just 500 images for training.
#
# If we try to train a high-capacity model like a ConvNet on this small amount of data, we expect to overfit, and end up with a solution that does not generalize. We will see that we can drastically reduce overfitting by using dropout and data augmentation.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt
from time import time
from cs231n.layers import *
from cs231n.fast_layers import *

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# # Load data
# For this exercise our training set will contain 500 images and our validation and test sets will contain 1000 images as usual.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=500, num_validation=1000, num_test=1000, normalize=True):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    if normalize:
        mean_image = np.mean(X_train, axis=0)
        X_train -= mean_image
        X_val -= mean_image
        X_test -= mean_image
    
    # Transpose so that channels come first
    X_train = X_train.transpose(0, 3, 1, 2).copy()
    X_val = X_val.transpose(0, 3, 1, 2).copy()
    X_test = X_test.transpose(0, 3, 1, 2).copy()

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data(num_training=500)
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (500, 3, 32, 32)
# Train labels shape:  (500,)
# Validation data shape:  (1000, 3, 32, 32)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3, 32, 32)
# Test labels shape:  (1000,)

# %% [markdown]
# # Overfit
# Now that we've loaded our data, we will attempt to train a three layer convnet on this data. The three layer convnet has the architecture
#
# `conv - relu - pool - affine - relu - affine - softmax`
#
# We will use 32 5x5 filters, and our hidden affine layer will have 128 neurons.
#
# This is a very expressive model given that we have only 500 training samples, so we should expect to massively overfit this dataset, and achieve a training accuracy of nearly 0.9 with a much lower validation accuracy.

# %%
from cs231n.classifiers.convnet import *
from cs231n.classifier_trainer import ClassifierTrainer

model = init_three_layer_convnet(filter_size=5, num_filters=(32, 128))
trainer = ClassifierTrainer()
best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train, y_train, X_val, y_val, model, three_layer_convnet, dropout=None,
          reg=0.05, learning_rate=0.00005, batch_size=50, num_epochs=15,
          learning_rate_decay=1.0, update='rmsprop', verbose=True)
# Out:
# starting iteration  0
# Finished epoch 0 / 15: cost 5.032619, train: 0.104000, val 0.091000, lr 5.000000e-05
# Finished epoch 1 / 15: cost 4.152994, train: 0.324000, val 0.228000, lr 5.000000e-05
# starting iteration  10
# Finished epoch 2 / 15: cost 4.050589, train: 0.404000, val 0.230000, lr 5.000000e-05
# starting iteration  20
# Finished epoch 3 / 15: cost 3.676218, train: 0.488000, val 0.291000, lr 5.000000e-05
# starting iteration  30
# Finished epoch 4 / 15: cost 3.628319, train: 0.466000, val 0.262000, lr 5.000000e-05
# starting iteration  40
# Finished epoch 5 / 15: cost 3.357029, train: 0.662000, val 0.329000, lr 5.000000e-05
# starting iteration  50
# Finished epoch 6 / 15: cost 3.069165, train: 0.642000, val 0.323000, lr 5.000000e-05
# starting iteration  60
# Finished epoch 7 / 15: cost 3.128272, train: 0.650000, val 0.317000, lr 5.000000e-05
# starting iteration  70
# Finished epoch 8 / 15: cost 2.923193, train: 0.712000, val 0.335000, lr 5.000000e-05
# starting iteration  80
# Finished epoch 9 / 15: cost 2.780731, train: 0.790000, val 0.358000, lr 5.000000e-05
# starting iteration  90
# Finished epoch 10 / 15: cost 2.548146, train: 0.752000, val 0.325000, lr 5.000000e-05
# starting iteration  100
# Finished epoch 11 / 15: cost 2.726283, train: 0.818000, val 0.350000, lr 5.000000e-05
# starting iteration  110
# Finished epoch 12 / 15: cost 2.432530, train: 0.830000, val 0.344000, lr 5.000000e-05
# starting iteration  120
# Finished epoch 13 / 15: cost 2.445068, train: 0.878000, val 0.367000, lr 5.000000e-05
# starting iteration  130
# Finished epoch 14 / 15: cost 2.279496, train: 0.894000, val 0.357000, lr 5.000000e-05
# starting iteration  140
# Finished epoch 15 / 15: cost 2.283422, train: 0.892000, val 0.340000, lr 5.000000e-05
# finished optimization. best validation accuracy: 0.367000

# %%
# Visualize the loss and accuracy for our network trained on a small dataset

plt.subplot(2, 1, 1)
plt.plot(train_acc_history)
plt.plot(val_acc_history)
plt.title('accuracy vs time')
plt.legend(['train', 'val'], loc=4)
plt.xlabel('epoch')
plt.ylabel('classification accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss_history)
plt.title('loss vs time')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # Dropout
# The first way we will reduce overfitting is to use dropout.
#
# Open the file `cs231n/layers.py` and implement the `dropout_forward` and `dropout_backward` functions. We can check the forward pass by looking at the statistics of the outputs in train and test modes, and we can check the backward pass using numerical gradient checking.

# %%
# Check the dropout forward pass

x = np.random.randn(100, 100)
dropout_param_train = {'p': 0.25, 'mode': 'train'}
dropout_param_test = {'p': 0.25, 'mode': 'test'}

out_train, _ = dropout_forward(x, dropout_param_train)
out_test, _ = dropout_forward(x, dropout_param_test)

# Test dropout training mode; about 25% of the elements should be nonzero
print np.mean(out_train != 0)

# Test dropout test mode; all of the elements should be nonzero
print np.mean(out_test != 0)
# Out:
# 0.2577
# 1.0

# %%
from cs231n.gradient_check import eval_numerical_gradient_array

# Check the dropout backward pass

x = np.random.randn(5, 4)
dout = np.random.randn(*x.shape)
dropout_param = {'p': 0.8, 'mode': 'train', 'seed': 123}

dx_num = eval_numerical_gradient_array(lambda x: dropout_forward(x, dropout_param)[0], x, dout)

_, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)

# The error should be around 1e-12
print 'Testing dropout_backward function:'
print 'dx error: ', rel_error(dx_num, dx)
# Out:
# Testing dropout_backward function:
# dx error:  7.71652309365e-12

# %% [markdown]
# # Data Augmentation
# The next way we will reduce overfitting is to implement data augmentation. Since we have very little training data, we will use what little training data we have to generate artificial data, and use this artificial data to train our network.
#
# CIFAR-10 images are 32x32, and up until this point we have used the entire image as input to our convnets. Now we will do something different: our convnet will expect a smaller input (say 28x28). Instead of feeding our training images directly to the convnet, at training time we will randomly crop each training image to 28x28, randomly flip half of the training images horizontally, and randomly adjust the contrast and tint of each training image.
#
# Open the file `cs231n/data_augmentation.py` and implement the `random_flips`, `random_crops`, `random_contrast`, and `random_tint` functions. In the same file we have implemented the `fixed_crops` function to get you started. When you are done you can run the cell below to visualize the effects of each type of data augmentation.

# %%
from cs231n.data_augmentation import *

X = get_CIFAR10_data(num_training=100, normalize=False)[0]
num_imgs = 8
print X.dtype
#X = X[np.random.randint(100, size=num_imgs)]
img_index = 13
X = X[img_index + np.ones(num_imgs, dtype='int32')]

X_flip = random_flips(X)
X_rand_crop = random_crops(X, (28, 28))

# To give more dramatic visualizations we use large scales for random contrast
# and tint adjustment.
X_contrast = random_contrast(X, scale=(0.5, 1.0))
X_tint = random_tint(X, scale=(-50, 50))

next_plt = 1
for i in xrange(num_imgs):
    titles = ['original', 'flip', 'rand crop', 'contrast', 'tint']
    for j, XX in enumerate([X, X_flip, X_rand_crop, X_contrast, X_tint]):
        plt.subplot(num_imgs, 5, next_plt)
        img = XX[i].transpose(1, 2, 0)
        if j == 4:
            # For visualization purposes we rescale the pixel values of the
            # tinted images
            low, high = np.min(img), np.max(img)
            img = 255 * (img - low) / (high - low)
        plt.imshow(img.astype('uint8'))
        if i == 0:
            plt.title(titles[j])
        plt.gca().axis('off')
        next_plt += 1
plt.show()
# Out:
# float64

# %% [markdown]
# # Train again
# We will now train a new network with the same training data and the same architecture, but using data augmentation and dropout.
#
# If everything works, you should see a higher validation accuracy than above and a smaller gap between the training accuracy and the validation accuracy.
#
# Networks with dropout usually take a bit longer to train, so we will use more training epochs this time.

# %%
input_shape = (3, 28, 28)

def augment_fn(X):
    out = random_flips(random_crops(X, input_shape[1:]))
    out = random_tint(random_contrast(out))
    return out

def predict_fn(X):
    return fixed_crops(X, input_shape[1:], 'center')
    
model = init_three_layer_convnet(filter_size=5, input_shape=input_shape, num_filters=(32, 128))
trainer = ClassifierTrainer()

best_model, loss_history, train_acc_history, val_acc_history = trainer.train(
          X_train, y_train, X_val, y_val, model, three_layer_convnet,
          reg=0.07, learning_rate=0.00005, learning_rate_decay=0.99,
          batch_size=50, num_epochs=50, update='rmsprop', verbose=True, dropout=0.5,
          augment_fn=augment_fn, predict_fn=predict_fn)

#The validation accuracy improves slightly from 0.367 to 0.403
# No overfitting is seen in training accuracy
# Out:
# starting iteration  0
# Finished epoch 0 / 50: cost 5.221459, train: 0.134000, val 0.092000, lr 5.000000e-05
# Finished epoch 1 / 50: cost 4.612958, train: 0.272000, val 0.221000, lr 4.950000e-05
# starting iteration  10
# Finished epoch 2 / 50: cost 4.420293, train: 0.268000, val 0.232000, lr 4.900500e-05
# starting iteration  20
# Finished epoch 3 / 50: cost 4.307439, train: 0.340000, val 0.272000, lr 4.851495e-05
# starting iteration  30
# Finished epoch 4 / 50: cost 4.152866, train: 0.354000, val 0.286000, lr 4.802980e-05
# starting iteration  40
# Finished epoch 5 / 50: cost 3.868932, train: 0.380000, val 0.294000, lr 4.754950e-05
# starting iteration  50
# Finished epoch 6 / 50: cost 3.928302, train: 0.386000, val 0.297000, lr 4.707401e-05
# starting iteration  60
# Finished epoch 7 / 50: cost 3.785466, train: 0.446000, val 0.318000, lr 4.660327e-05
# starting iteration  70
# Finished epoch 8 / 50: cost 3.944670, train: 0.446000, val 0.333000, lr 4.613723e-05
# starting iteration  80
# Finished epoch 9 / 50: cost 3.835754, train: 0.454000, val 0.342000, lr 4.567586e-05
# starting iteration  90
# Finished epoch 10 / 50: cost 3.693499, train: 0.452000, val 0.335000, lr 4.521910e-05
# starting iteration  100
# Finished epoch 11 / 50: cost 3.500691, train: 0.466000, val 0.353000, lr 4.476691e-05
# starting iteration  110
# Finished epoch 12 / 50: cost 3.405373, train: 0.478000, val 0.337000, lr 4.431924e-05
# starting iteration  120
# Finished epoch 13 / 50: cost 3.598687, train: 0.470000, val 0.337000, lr 4.387605e-05
# starting iteration  130
# Finished epoch 14 / 50: cost 3.363321, train: 0.508000, val 0.366000, lr 4.343729e-05
# starting iteration  140
# Finished epoch 15 / 50: cost 3.428177, train: 0.520000, val 0.360000, lr 4.300292e-05
# starting iteration  150
# Finished epoch 16 / 50: cost 3.262967, train: 0.518000, val 0.378000, lr 4.257289e-05
# starting iteration  160
# Finished epoch 17 / 50: cost 3.382011, train: 0.540000, val 0.358000, lr 4.214716e-05
# starting iteration  170
# Finished epoch 18 / 50: cost 3.153150, train: 0.536000, val 0.359000, lr 4.172569e-05
# starting iteration  180
# Finished epoch 19 / 50: cost 3.063918, train: 0.536000, val 0.368000, lr 4.130843e-05
# starting iteration  190
# Finished epoch 20 / 50: cost 3.398533, train: 0.532000, val 0.362000, lr 4.089535e-05
# starting iteration  200
# Finished epoch 21 / 50: cost 2.938209, train: 0.564000, val 0.389000, lr 4.048639e-05
# starting iteration  210
# Finished epoch 22 / 50: cost 2.960789, train: 0.552000, val 0.373000, lr 4.008153e-05
# starting iteration  220
# Finished epoch 23 / 50: cost 3.074816, train: 0.558000, val 0.368000, lr 3.968071e-05
# starting iteration  230
# Finished epoch 24 / 50: cost 2.926839, train: 0.568000, val 0.382000, lr 3.928391e-05
# starting iteration  240
# Finished epoch 25 / 50: cost 2.792417, train: 0.572000, val 0.388000, lr 3.889107e-05
# starting iteration  250
# Finished epoch 26 / 50: cost 3.077391, train: 0.590000, val 0.393000, lr 3.850216e-05
# starting iteration  260
# Finished epoch 27 / 50: cost 2.894541, train: 0.570000, val 0.393000, lr 3.811714e-05
# starting iteration  270
# Finished epoch 28 / 50: cost 2.791177, train: 0.600000, val 0.396000, lr 3.773596e-05
# starting iteration  280
# Finished epoch 29 / 50: cost 2.769863, train: 0.592000, val 0.377000, lr 3.735860e-05
# starting iteration  290
# Finished epoch 30 / 50: cost 2.904577, train: 0.616000, val 0.390000, lr 3.698502e-05
# starting iteration  300
# Finished epoch 31 / 50: cost 3.007468, train: 0.608000, val 0.403000, lr 3.661517e-05
# starting iteration  310
# Finished epoch 32 / 50: cost 2.648536, train: 0.616000, val 0.389000, lr 3.624902e-05
# starting iteration  320
# Finished epoch 33 / 50: cost 2.834796, train: 0.608000, val 0.392000, lr 3.588653e-05
# starting iteration  330
# Finished epoch 34 / 50: cost 2.525834, train: 0.600000, val 0.398000, lr 3.552766e-05
# starting iteration  340
# Finished epoch 35 / 50: cost 2.820360, train: 0.630000, val 0.400000, lr 3.517238e-05
# starting iteration  350
# Finished epoch 36 / 50: cost 2.519416, train: 0.636000, val 0.396000, lr 3.482066e-05
# starting iteration  360
# Finished epoch 37 / 50: cost 2.927227, train: 0.622000, val 0.385000, lr 3.447245e-05
# starting iteration  370
# Finished epoch 38 / 50: cost 2.885057, train: 0.640000, val 0.392000, lr 3.412773e-05
# starting iteration  380
# Finished epoch 39 / 50: cost 2.723904, train: 0.648000, val 0.382000, lr 3.378645e-05
# starting iteration  390
# Finished epoch 40 / 50: cost 2.852810, train: 0.652000, val 0.378000, lr 3.344859e-05
# starting iteration  400
# Finished epoch 41 / 50: cost 2.648274, train: 0.658000, val 0.394000, lr 3.311410e-05
# starting iteration  410
# Finished epoch 42 / 50: cost 2.774039, train: 0.658000, val 0.389000, lr 3.278296e-05
# starting iteration  420
# Finished epoch 43 / 50: cost 2.738306, train: 0.664000, val 0.394000, lr 3.245513e-05
# starting iteration  430
# Finished epoch 44 / 50: cost 2.572123, train: 0.670000, val 0.384000, lr 3.213058e-05
# starting iteration  440
# Finished epoch 45 / 50: cost 2.660316, train: 0.668000, val 0.395000, lr 3.180927e-05
# starting iteration  450
# Finished epoch 46 / 50: cost 2.778039, train: 0.676000, val 0.401000, lr 3.149118e-05
# starting iteration  460
# Finished epoch 47 / 50: cost 2.540719, train: 0.674000, val 0.393000, lr 3.117627e-05
# starting iteration  470
# Finished epoch 48 / 50: cost 2.706264, train: 0.680000, val 0.390000, lr 3.086451e-05
# starting iteration  480
# Finished epoch 49 / 50: cost 2.529421, train: 0.674000, val 0.397000, lr 3.055586e-05
# starting iteration  490
# Finished epoch 50 / 50: cost 2.561321, train: 0.674000, val 0.388000, lr 3.025030e-05
# finished optimization. best validation accuracy: 0.403000

# %%
# Visualize the loss and accuracy for our network trained with dropout and data augmentation.
# You should see less overfitting, and you may also see slightly better performance on the
# validation set.

plt.subplot(2, 1, 1)
plt.plot(train_acc_history)
plt.plot(val_acc_history)
plt.title('accuracy vs time')
plt.legend(['train', 'val'], loc=4)
plt.xlabel('epoch')
plt.ylabel('classification accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss_history)
plt.title('loss vs time')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()
